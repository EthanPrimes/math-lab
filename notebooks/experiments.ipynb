# %%
import re
import sys
from time import perf_counter as pf

from core.primes import is_prime, pollards_rho_algorithm, regex_is_prime

# %%
n = 104729
start = pf()
res = regex_is_prime(n)
print("Regex Approach:")
print(f"Time: {pf() - start}")
print(f"Result: {res}\n")

start = pf()
res = is_prime(n)
print("Standard Approach:")
print(f"Time: {pf() - start}")
print(f"Result: {res}")
# Out:
# Regex Approach:
# Time: 1.92597687500529
# Result: True
#
# Standard Approach:
# Time: 4.4042011722922325e-05
# Result: True

# %%
print(f"The string takes {sys.getsizeof("1" * n) / 10**6} Mb of storage")
# Out:
# The string takes 0.10477 Mb of storage

# %%
regex_is_prime(65537)
# Out:
# True

# %%
pollards_rho_algorithm(2**32 + 1)
# Out:
# 641

# %%
res = 1,
res
# Out:
# (1,)

# %%
a = 1
b = 0
if (x := a - b):
    print(x)
# Out:
# 1

# %%
res = b"h\x65llo"
print(type(res))
print(list(res))
print(res)
# Out:
# <class 'bytes'>
# [104, 101, 108, 108, 111]
# b'hello'

# %%
N = 5
for i in range(1, N):
    for j in range(1, N):
        print(2*(2*i*j + i + j) + 1)
# Out:
# 9
# 15
# 21
# 27
# 15
# 25
# 35
# 45
# 21
# 35
# 49
# 63
# 27
# 45
# 63
# 81

# %%
def t(n): return n * (n+1) / 2

for k in range(-1000, 1000):
    tk = t(k)
    if t(round(pow(2 * tk, 1/2))) != tk:
        print(k)
        print(tk)
