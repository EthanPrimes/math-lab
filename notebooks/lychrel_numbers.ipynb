# %%
from math import floor, log10

# %%
def max_steps_n_digits(n):
    # Determines the max # of steps it takes for any n digit
    # number to reach or pass the next power of 10
    bound = 10**(n)
    max_steps = 0
    for i in range(10**(n - 1), 10**n):
        s = i
        steps = 0
        while s < bound:
            s += int(str(s)[::-1])
            steps += 1

        # print(f"{i} - {steps} steps")
        max_steps = max(max_steps, steps)

    return max_steps

for i in range(1, 10):
    print(max_steps_n_digits(i))
# Out:
# 4
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 5

# %%
bin_lychrel("111")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 bin_lychrel("111")
#
# Cell In[31], line 3, in bin_lychrel(b)
#       1 def bin_lychrel(b):
#       2     b = bin(int(b, 2))
# ----> 3     return b + int("0b" + str(b)[:-2:-1], 2)
#
# TypeError: can only concatenate str (not "int") to str
